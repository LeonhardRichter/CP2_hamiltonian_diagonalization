# %%
from dicke import dicke_hamiltonian, dicke_hamiltonian_full
import matplotlib.pyplot as plt

# %%
H = dicke_hamiltonian(5, 10)
plt.spy(H, marker="s", markersize=3, alpha=0.5, color="tab:blue")
plt.savefig(
    "figures/sparse_visual_N{5}_nmax{10}_dicke_basis.svg",
    format="svg",
    bbox_inches="tight",
    transparent=True,
)
