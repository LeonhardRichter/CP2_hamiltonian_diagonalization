# %%
from dicke import dicke_hamiltonian, dicke_hamiltonian_full
import matplotlib.pyplot as plt

# %%
N = 100
n = 200
H = dicke_hamiltonian(N, n)
plt.spy(H, marker="s", markersize=1, alpha=0.2, color="tab:blue")
plt.savefig(
    f"figures/sparse_visual_N{N}_nmax{n}_dicke_basis.png",
    format="png",
    bbox_inches="tight",
    transparent=True,
    dpi=600,
)
